# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
dbutils.widgets.text("incremental_flag","0")

# %%
dbutils.widgets.get("incremental_flag")

# %%
df_src=spark.sql('''
                 select distinct(customer_id) as customer_id, first_name, last_name, email, gender, Address, city, state, country, zipcode, phone, Created_date, loyalty, Addressline1, Addressline2 from delta.`/mnt/bayerhackathon/squad2-bhargav/silver/customer`''')

# %%
df_src.display()

# %%
if("incremental_flag"=="0"):
    max_value=1
else:
    max_value_df=spark.sql("select max(customer_id) as max_value from delta.`/mnt/bayerhackathon/squad2-bhargav/silver/customer`")
    max_value=max_value_df.collect()[0][0]

# %%
df_filter_new=df_filter_new.withColumn("customer_id",max_value+monotonically_increasing_id())
